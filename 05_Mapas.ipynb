# %% [markdown]
# # Mapas
#
# [Cartopy](https://scitools.org.uk/cartopy/) es un paquete de Python diseñado para el procesamiento de datos geoespaciales, para su análisis y representación a través de mapas.
#
# Cartopy utiliza las librerías [PROJ.4](https://proj.org/), NumPy and [Shapely](https://shapely.readthedocs.io/) e incluye una interfaz basada en Matplotlib para la creación de mapas de alta calidad.
#
# Para cada Mapa, lo primero es definir la [proyección](https://bl.ocks.org/syntagmatic/ba569633d51ebec6ec6e), que define un sistema coordenado de referencia ([CCRS](https://scitools.org.uk/cartopy/docs/latest/crs/projections.html): Cartopy Coordinate Reference Systems).

# %% [markdown]
# ### Instalación del módulo Cartopy en AWS/Linux/conda
#
# ```bash
# $ conda config --set channel_priority false
# $ conda update --all --yes
# $ conda install -c conda-forge cartopy
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
import io
from urllib.request import urlopen, Request
from PIL import Image

# %%
conda install cartopy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                     |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - anaconda==2021.05 -> python[version='3.7.10|3.9.4|3.8.8',build='hdb3f193_0|hdb3f193_5']
#   - appdirs -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - argon2-cffi -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - atomicwrites -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - attrs -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - autopep8 -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#   - bleach -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - colorama -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda-verify -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda[version='>=4.10.1'] -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - contextlib2 -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - filelock -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - flake8 -> python[version='>=3.9,<3.10.0a0']
#   - flask -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - glob2 -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - h5py -> python[version='<3']
#   - html5lib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - imagesize -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - ipywidgets -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - isort -> python[version='>=3.9,<3.10.0a0']
#   - jdcal -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - jupyter_console -> python[version='>=3.9,<3.10.0a0']
#   - matplotlib-base -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - mock -> python[version='>=3.9,<3.10.0a0']
#   - more-itertools -> python[version='>=3.9,<3.10.0a0']
#   - nose -> python[version='>=3.9,<3.10.0a0']
#   - numba -> python=3.4
#   - olefile -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - packaging -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - path -> python[version='>=2.7,<2.8.0a0']
#   - pickleshare -> python[version='>=3.9,<3.10.0a0']
#   - prometheus_client -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pycparser -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - pyflakes -> python[version='>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyparsing -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pytz -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - qtpy -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - rope -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - sniffio -> python[version='>=3,<3.7']
#   - sortedcollections -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - sphinxcontrib-websupport -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - tblib -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - testpath -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - tifffile -> python[version='>=2.7,<2.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - typing_extensions -> python[version='>=3.9,<3.10.0a0']
#   - watchdog -> python[version='>=3.5,<3.6.0a0']
#   - werkzeug -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - wheel -> python[version='>=3.9,<3.10.0a0']
#   - wurlitzer -> python[version='<3.4']
#   - xlrd -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - xlsxwriter -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - xmltodict -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - yapf -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zict -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package typing_extensions conflicts for:
# black -> typing_extensions
# anyio -> typing_extensions
# jupyter_server -> anyio[version='>=2.0.2'] -> typing_extensions
# anaconda==2021.05 -> typing_extensions==3.7.4.3=pyha847dfd_0
# pyls-black -> black -> typing_extensions
# anaconda==2021.05 -> anyio==2.2.0=py37h06a4308_1 -> typing_extensions[version='>=3.6.4|>=3.7.4']
# sqlalchemy -> importlib-metadata -> typing_extensions[version='>=3.6.4']
# click -> importlib-metadata -> typing_extensions[version='>=3.6.4']
# importlib-metadata -> typing_extensions[version='>=3.6.4']
# astroid -> typing-extensions[version='>=3.7.4'] -> typing_extensions[version='3.7.4|3.7.4.1|3.7.4.2|3.7.4.3',build='pyh06a4308_0|py_0|py_0|py38_0|py36_0']
# importlib_metadata -> importlib-metadata[version='>=3.10.0,<3.10.1.0a0'] -> typing_extensions[version='>=3.6.4']
# flake8 -> importlib-metadata -> typing_extensions[version='>=3.6.4']
# pytest -> importlib-metadata[version='>=0.12'] -> typing_extensions[version='>=3.6.4']
# bokeh -> typing_extensions[version='>=3.7.4']
# keyring -> importlib-metadata -> typing_extensions[version='>=3.6.4']
# dask -> bokeh[version='>=1.0.0,!=2.0.0'] -> typing_extensions[version='>=3.7.4']
#
# Package pytz conflicts for:
# sphinx -> babel[version='>=1.3'] -> pytz[version='>=2015.7']
# babel -> pytz[version='>=2015.7']
# seaborn -> matplotlib[version='>=2.1.2'] -> pytz[version='>=2017.2|>=2017.3']
# scikit-image -> matplotlib[version='>=2.0.0'] -> pytz
# conda-repo-cli -> pytz
# anaconda==2021.05 -> pytz==2021.1=pyhd3eb1b0_0
# anaconda-client -> pytz
# matplotlib -> pytz
# pandas -> pytz[version='>=2017.2|>=2017.3']
# jupyterlab_server -> babel -> pytz[version='>=2015.7']
# astropy -> matplotlib[version='>=3.0'] -> pytz
# statsmodels -> pandas[version='>=0.21'] -> pytz[version='>=2017.2|>=2017.3']
# bokeh -> matplotlib -> pytz[version='>=2017.2|>=2017.3']
# nltk -> matplotlib -> pytz
# anaconda-project -> anaconda-client -> pytz
# conda-build -> pytz
# anaconda-navigator -> anaconda-client[version='>=1.6.14'] -> pytz
# dask -> pandas[version='>=0.25.0'] -> pytz[version='>=2017.2|>=2017.3']
# anaconda==2021.05 -> anaconda-client==1.7.2=py37_0 -> pytz[version='>=2017.3']
# cartopy -> matplotlib -> pytz
# bkcharts -> pandas -> pytz[version='>=2017.2|>=2017.3']
#
# Package setuptools conflicts for:
# sympy -> setuptools
# isort -> setuptools
# dask -> distributed=2021.6.0 -> setuptools
# zope.event -> setuptools
# flake8 -> setuptools[version='>=30.0.0']
# jinja2 -> setuptools
# qtconsole -> pygments -> setuptools
# jsonschema -> setuptools
# pytest -> setuptools[version='>=40.0']
# jupyter_server -> jinja2 -> setuptools
# python-language-server -> setuptools
# joblib -> setuptools
# soupsieve -> backports.functools_lru_cache -> setuptools
# python=3.8 -> pip -> setuptools
# ipywidgets -> ipython[version='>=4.0.0'] -> setuptools[version='>=18.5']
# cython -> setuptools
# ipykernel -> ipython[version='>=5.0'] -> setuptools[version='>=18.5']
# jupyterlab -> ipython -> setuptools[version='>=18.5']
# astropy -> pytest[version='<4'] -> setuptools[version='>=40.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> setuptools
# anaconda-project -> anaconda-client -> setuptools
# nose -> setuptools
# backports.functools_lru_cache -> setuptools
# ipython -> pygments -> setuptools
# anaconda==2021.05 -> anaconda-client==1.7.2=py37_0 -> setuptools[version='>=18.5|>=30.0.0|>=39.0.0']
# conda-build -> setuptools
# matplotlib-base -> setuptools
# wheel -> setuptools
# prompt_toolkit -> pygments -> setuptools
# pip -> setuptools
# jupyter_console -> ipython -> setuptools[version='>=18.5']
# gevent -> setuptools
# bokeh -> jinja2[version='>=2.9'] -> setuptools
# astropy -> setuptools
# conda-build -> conda[version='>=4.5'] -> setuptools[version='>=31.0.1']
# numpydoc -> sphinx -> setuptools
# prompt-toolkit -> pygments -> setuptools
# pygments -> setuptools
# pyflakes -> setuptools
# ipython -> setuptools[version='>=18.5']
# pyls-spyder -> python-language-server[version='>=0.36.2'] -> setuptools
# nbconvert -> bleach -> setuptools
# notebook -> jinja2 -> setuptools
# conda-repo-cli -> setuptools
# matplotlib -> setuptools
# conda-token -> conda[version='>=4.3'] -> setuptools[version='>=31.0.1']
# cartopy -> matplotlib-base[version='>=1.5.1'] -> setuptools
# networkx -> setuptools
# zope.interface -> setuptools
# anaconda-client -> setuptools
# scikit-image -> matplotlib-base[version='>=2.0.0'] -> setuptools
# jupyterlab_pygments -> pygments[version='>=2.4.1,<3'] -> setuptools
# clyent -> setuptools
# conda[version='>=4.10.1'] -> setuptools[version='>=31.0.1']
# anaconda==2021.05 -> setuptools==52.0.0[build='py38h06a4308_0|py37h06a4308_0|py39h06a4308_0']
# scikit-learn -> joblib[version='>=0.11'] -> setuptools
# numba -> setuptools
# seaborn -> matplotlib[version='>=2.1.2'] -> setuptools
# flask -> jinja2[version='>=2.10.1'] -> setuptools
# anaconda-navigator -> setuptools
# pylint -> astroid[version='>=2.5.8,<=2.7'] -> setuptools
# bleach -> setuptools
# astroid -> setuptools
# nltk -> joblib -> setuptools
# flake8 -> pyflakes[version='>=1.5.0,<1.7.0'] -> setuptools
# attrs -> zope.interface -> setuptools
# jupyter-packaging -> setuptools
# python-language-server -> flake8[version='>=3.8.0'] -> setuptools[version='>=30.0.0']
# distributed -> setuptools
# conda-verify -> backports.functools_lru_cache -> setuptools
# sphinx -> setuptools
# spyder -> setuptools[version='>=39.0.0']
# jupyterlab_server -> jinja2[version='>=2.10'] -> setuptools
# spyder -> ipython[version='>=7.6.0'] -> setuptools[version='>=18.5']
# pyls-black -> python-language-server -> setuptools
# spyder-kernels -> ipython[version='>=7.6.0'] -> setuptools[version='>=18.5']
#
# Package zlib conflicts for:
# filelock -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# psutil -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pytz -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# networkx -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pygments -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# six -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# rope -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# future -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# fsspec -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyls-spyder -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-repo-cli -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# cycler -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# argon2-cffi -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# gevent -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jsonschema -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_server -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pylint -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# imagesize -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# typing_extensions -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter-packaging -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libllvm10 -> zlib[version='>=1.2.11,<1.3.0a0']
# three-merge -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# msgpack-python -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# distributed -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python-libarchive-c -> libarchive -> zlib[version='>=1.2.11,<1.3.0a0']
# tifffile -> imagecodecs[version='>=2021.3.31'] -> zlib[version='>=1.2.11,<1.3.0a0']
# rtree -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# babel -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backports.tempfile -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# nltk -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# docutils -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# regex -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# send2trash -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda==2021.05 -> zlib==1.2.11=h7b6447c_3
# keyring -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pip -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda-client -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pycurl -> libcurl[version='>=7.71.1,<8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# partd -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tqdm -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sortedcontainers -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ipython_genutils -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# glob2 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# numexpr -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-token -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# lxml -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sympy -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mpmath -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda-navigator -> pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# qdarkstyle -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# scikit-learn -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# xlwt -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-content-trust -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# anyio -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ujson -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pytables -> zlib[version='>=1.2.11,<1.3.0a0']
# pango -> zlib[version='>=1.2.11,<1.3.0a0']
# flask -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# unicodecsv -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# seaborn -> matplotlib[version='>=2.1.2'] -> zlib[version='>=1.2.11,<1.3.0a0']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pydocstyle -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# isort -> python[version='>=3.6,<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# lazy-object-proxy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pycparser -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# jdcal -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# chardet -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# defusedxml -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf5 -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# numba -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mypy_extensions -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# bleach -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# sip -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# secretstorage -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyxdg -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# libcurl -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinx -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# path.py -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libxslt -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# soupsieve -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pandoc -> zlib
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0']
# pyflakes -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# watchdog -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# numpydoc -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# wcwidth -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# qtconsole -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# h5py -> hdf5[version='>=1.10.6,<1.10.7.0a0'] -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0']
# itsdangerous -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# locket -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pexpect -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# more-itertools -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# requests -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# scipy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# nbclient -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# jinja2 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# atomicwrites -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# boto -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# idna -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cytoolz -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0']
# prometheus_client -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# iniconfig -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# yapf -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pytables -> hdf5[version='>=1.8.18,<1.8.19.0a0'] -> zlib=1.2
# zipp -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backports.functools_lru_cache -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# traitlets -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# fastcache -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mock -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda[version='>=4.10.1'] -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# prompt_toolkit -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backcall -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pathlib2 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# xlsxwriter -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# astropy -> matplotlib[version='>=3.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cartopy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# gst-plugins-base -> zlib[version='>=1.2.11,<1.3.0a0']
# flake8 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# imageio -> pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3 -> python[version='<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# scikit-image -> pillow[version='>=4.3.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# beautifulsoup4 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# dask-core -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ruamel_yaml -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyopenssl -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyterlab_pygments -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# attrs -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pywavelets -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-package-handling -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-websupport -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# typed-ast -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# py-lief -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# packaging -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pycodestyle -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pyerfa -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# contextlib2 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sniffio -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_client -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sortedcollections -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# python-dateutil -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# curl -> zlib[version='>=1.2.11,<1.3.0a0']
# backports -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib-base -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backports.weakref -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# krb5 -> tk[version='>=8.6.8,<8.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# qtawesome -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pickleshare -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# asn1crypto -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# async_generator -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# colorama -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# glib -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_console -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# appdirs -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# parso -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cffi -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# html5lib -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pep8 -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# zope.event -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jeepney -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mccabe -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backports.shutil_get_terminal_size -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# autopep8 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pathspec -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# cloudpickle -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# textdistance -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# black -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# llvmlite -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda==2021.05 -> blosc==1.21.0=h8c45485_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# tornado -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cairo -> zlib[version='>=1.2.11,<1.3.0a0']
# dbus -> glib -> zlib[version='>=1.2.11,<1.3.0a0']
# pytest -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# testpath -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# astroid -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# nbformat -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# xlrd -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# numpy-base -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# multipledispatch -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# patsy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# joblib -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# clyent -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# diff-match-patch -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# bkcharts -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# werkzeug -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# gmpy2 -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# qtpy -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# singledispatch -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# nbconvert -> pandoc[version='>=1.12.1'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# toml -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pandocfilters -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mkl_random -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# zope.interface -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ipywidgets -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# openpyxl -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libarchive -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0']
# gstreamer -> glib[version='>=2.66.1,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# argh -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# setuptools -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# simplegeneric -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# zope -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# click -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-verify -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyterlab -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# heapdict -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# mkl-service -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# toolz -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0']
# xmltodict -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# spyder -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# threadpoolctl -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# alabaster -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# importlib-metadata -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# py -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# wheel -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# harfbuzz -> cairo[version='>=1.14.12,<2.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pluggy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# intervaltree -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# nose -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyparsing -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# python-jsonrpc-server -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# conda-build -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# path -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ptyprocess -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# json5 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# dask -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# wurlitzer -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# certifi -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# greenlet -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# zict -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlalchemy -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# decorator -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# nest-asyncio -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# mistune -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python-language-server -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ply -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pkginfo -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# blosc -> zlib[version='>=1.2.11,<1.3.0a0']
# pyyaml -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# nbclassic -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# qt -> zlib[version='>=1.2.11,<1.3.0a0']
# spyder-kernels -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tblib -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# statsmodels -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python=3.8 -> zlib[version='>=1.2.11,<1.3.0a0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyodbc -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# anaconda-project -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cryptography -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package tzdata conflicts for:
# anaconda-client -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# watchdog -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# beautifulsoup4 -> python[version='>=3.6'] -> tzdata
# packaging -> python -> tzdata
# docutils -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# async_generator -> python[version='>2.7'] -> tzdata
# rtree -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# zope.event -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# dask -> python[version='>=3.7'] -> tzdata
# terminado -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# chardet -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# matplotlib -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# prometheus_client -> python -> tzdata
# locket -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sqlalchemy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# typing_extensions -> python[version='>=3.5'] -> tzdata
# toolz -> python[version='>=3.5'] -> tzdata
# appdirs -> python -> tzdata
# mock -> python[version='>=3.6'] -> tzdata
# tblib -> python -> tzdata
# pkginfo -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# backcall -> python -> tzdata
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# fsspec -> python[version='>=3.6'] -> tzdata
# prompt_toolkit -> python[version='>=3.6'] -> tzdata
# autopep8 -> python -> tzdata
# mistune -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# zope.interface -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pillow -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# contextlib2 -> python -> tzdata
# argon2-cffi -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# xlrd -> python -> tzdata
# patsy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyter_client -> python[version='>=3.5'] -> tzdata
# mpmath -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# diff-match-patch -> python -> tzdata
# sortedcontainers -> python[version='>=2.7'] -> tzdata
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# kiwisolver -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# networkx -> python[version='>=3.6'] -> tzdata
# werkzeug -> python -> tzdata
# imageio -> python[version='>=3'] -> tzdata
# gmpy2 -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# cffi -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# conda-build -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# python-libarchive-c -> python -> tzdata
# keyring -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# anaconda==2021.05 -> python==3.9.4=hdb3f193_0 -> tzdata
# nltk -> python[version='>=3.5'] -> tzdata
# sip -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# conda-package-handling -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyterlab_widgets -> python[version='>=3.6'] -> tzdata
# typed-ast -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# toml -> python[version='>=2.7'] -> tzdata
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# numpy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pep8 -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sortedcollections -> python -> tzdata
# jeepney -> python[version='>=3.5'] -> tzdata
# babel -> python[version='>=3.6'] -> tzdata
# numba -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# backports.shutil_get_terminal_size -> python -> tzdata
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pycparser -> python -> tzdata
# setuptools -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# conda[version='>=4.10.1'] -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# lxml -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# mypy_extensions -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# python-dateutil -> python -> tzdata
# jupyter_server -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# bleach -> python -> tzdata
# testpath -> python -> tzdata
# colorama -> python -> tzdata
# ipywidgets -> python -> tzdata
# alabaster -> python -> tzdata
# nbconvert -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> tzdata
# flake8 -> python[version='>=3.6'] -> tzdata
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# mccabe -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# send2trash -> python -> tzdata
# bokeh -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# html5lib -> python -> tzdata
# llvmlite -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# cython -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# anyio -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# singledispatch -> python -> tzdata
# idna -> python[version='>=3.5'] -> tzdata
# json5 -> python -> tzdata
# zict -> python -> tzdata
# openpyxl -> python[version='>=3.6'] -> tzdata
# pathspec -> python -> tzdata
# nest-asyncio -> python[version='>=3.5'] -> tzdata
# ipython_genutils -> python -> tzdata
# xlwt -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jdcal -> python -> tzdata
# numpydoc -> python[version='>=3.5'] -> tzdata
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> tzdata
# yapf -> python -> tzdata
# psutil -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# tifffile -> python[version='>=3.7'] -> tzdata
# pandas -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# olefile -> python -> tzdata
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# anaconda-navigator -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyparsing -> python -> tzdata
# xmltodict -> python -> tzdata
# partd -> python[version='>=3.5'] -> tzdata
# astropy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinx -> python[version='>=3.6'] -> tzdata
# secretstorage -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# numpy-base -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pysocks -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# numexpr -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# conda-token -> python -> tzdata
# filelock -> python -> tzdata
# jupyterlab -> python[version='>=3.6'] -> tzdata
# more-itertools -> python[version='>=3.5'] -> tzdata
# jupyter_console -> python[version='>=3.6'] -> tzdata
# scipy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyls-spyder -> python[version='>=3.6'] -> tzdata
# anaconda==2021.05 -> tzdata==2020f=h52ac0ba_0
# seaborn -> python[version='>=3.6'] -> tzdata
# attrs -> python -> tzdata
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# cytoolz -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pydocstyle -> python[version='>=3.6'] -> tzdata
# spyder -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# isort -> python[version='>=3.6,<4.0'] -> tzdata
# pytz -> python -> tzdata
# zope -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# zipp -> python[version='>=3.6'] -> tzdata
# ptyprocess -> python -> tzdata
# spyder-kernels -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# bitarray -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# mkl_fft -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# click -> python[version='>=3.6'] -> tzdata
# pip -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# backports.tempfile -> python -> tzdata
# pytables -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# decorator -> python[version='>=3.5'] -> tzdata
# snowballstemmer -> python -> tzdata
# pyxdg -> python -> tzdata
# statsmodels -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# urllib3 -> python[version='<4.0'] -> tzdata
# xlsxwriter -> python -> tzdata
# fastcache -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# path.py -> python[version='>=3.5'] -> tzdata
# jedi -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# soupsieve -> python[version='>=3.5'] -> tzdata
# regex -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# wcwidth -> python -> tzdata
# intervaltree -> python -> tzdata
# pywavelets -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# wheel -> python -> tzdata
# pycodestyle -> python -> tzdata
# boto -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# clyent -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> tzdata
# python-jsonrpc-server -> python -> tzdata
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> tzdata
# conda-content-trust -> python -> tzdata
# glob2 -> python -> tzdata
# jupyter_core -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# ruamel_yaml -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# unicodecsv -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# gevent -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pylint -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# wurlitzer -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyter-packaging -> python[version='>=3.5'] -> tzdata
# pyerfa -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# three-merge -> python -> tzdata
# pyodbc -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# backports -> python -> tzdata
# conda-repo-cli -> python -> tzdata
# dask-core -> python[version='>=3.7'] -> tzdata
# imagesize -> python -> tzdata
# notebook -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# brotlipy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyterlab_server -> python[version='>=3.6'] -> tzdata
# py-lief -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pygments -> python[version='>=3.5'] -> tzdata
# py -> python[version='>=2.7'] -> tzdata
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# certifi -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# joblib -> python[version='>=3.6'] -> tzdata
# tqdm -> python[version='>=2.7'] -> tzdata
# scikit-image -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# tornado -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# matplotlib-base -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# future -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyflakes -> python -> tzdata
# qtpy -> python -> tzdata
# pyopenssl -> python -> tzdata
# ujson -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# itsdangerous -> python[version='>=3.6'] -> tzdata
# mkl-service -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# cloudpickle -> python[version='>=3.5'] -> tzdata
# jsonschema -> python[version='>=3.6'] -> tzdata
# parso -> python[version='>=3.6'] -> tzdata
# heapdict -> python -> tzdata
# backports.functools_lru_cache -> python -> tzdata
# pickleshare -> python[version='>=3'] -> tzdata
# qtconsole -> python[version='>=3.6'] -> tzdata
# prompt-toolkit -> python[version='>=3.6'] -> tzdata
# ipython -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pathlib2 -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# textdistance -> python[version='>=2.7'] -> tzdata
# flask -> python -> tzdata
# pyyaml -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# astroid -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# argh -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# path -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> tzdata
# pytest -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# black -> python[version='>=3.6'] -> tzdata
# msgpack-python -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# lazy-object-proxy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# threadpoolctl -> python[version='>=3.5'] -> tzdata
# pluggy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# qdarkstyle -> python -> tzdata
# multipledispatch -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# simplegeneric -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# distributed -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# nose -> python[version='>=3.6'] -> tzdata
# nbclient -> python[version='>=3.6'] -> tzdata
# greenlet -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jinja2 -> python[version='>=3.6'] -> tzdata
# python-language-server -> python[version='>=3.6'] -> tzdata
# cycler -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> tzdata
# pycosat -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyterlab_pygments -> python -> tzdata
# pycurl -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# nbclassic -> python[version='>=3.6'] -> tzdata
# requests -> python -> tzdata
# defusedxml -> python -> tzdata
# conda-verify -> python -> tzdata
# atomicwrites -> python -> tzdata
# traitlets -> python[version='>=3.7'] -> tzdata
# sympy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# backports.weakref -> python -> tzdata
# ply -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# iniconfig -> python -> tzdata
# anaconda-project -> python[version='>=2.7'] -> tzdata
# h5py -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# mkl_random -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# sphinxcontrib-websupport -> python -> tzdata
# nbformat -> python[version='>=3.5'] -> tzdata
# six -> python -> tzdata
# cartopy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# rope -> python -> tzdata
# qtawesome -> python[version='>=3.6'] -> tzdata
# asn1crypto -> python -> tzdata
# bkcharts -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pexpect -> python -> tzdata
# pandocfilters -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# markupsafe -> python[version='>=3.9,<3.10.0a0'] -> tzdata
#
# Package joblib conflicts for:
# nltk -> joblib
# anaconda==2021.05 -> nltk==3.6.1=pyhd3eb1b0_0 -> joblib[version='>=0.11']
# anaconda==2021.05 -> joblib==1.0.1=pyhd3eb1b0_0
# nltk -> scikit-learn -> joblib[version='>=0.11']
# scikit-learn -> joblib[version='>=0.11']
#
# Package jupyter_server conflicts for:
# anaconda==2021.05 -> jupyterlab==3.0.14=pyhd3eb1b0_1 -> jupyter_server[version='>=1.0.1,<2.0.0|>=1.1.0,<2.0.0|>=1.4,<2']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyter_server[version='>=1.4,<2']
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> jupyter_server[version='>=1.0.1,<2.0.0|>=1.1.0,<2.0.0']
# jupyterlab -> jupyter_server[version='>=1.4,<2']
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0']
# anaconda==2021.05 -> jupyter_server==1.4.1[build='py38h06a4308_0|py37h06a4308_0|py39h06a4308_0']
# nbclassic -> jupyter_server[version='>=1.0.1,<2.0.0']
#
# Package certifi conflicts for:
# astropy -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# terminado -> tornado[version='>=4'] -> certifi
# matplotlib-base -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# cython -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# astroid -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# sphinx -> requests[version='>=2.5.0'] -> certifi[version='>=2016.09|>=2016.9.26|>=2017.4.17']
# isort -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# conda-repo-cli -> requests[version='>=2.9.1'] -> certifi[version='>=2016.09|>=2016.9.26|>=2017.4.17']
# jupyterlab_server -> requests -> certifi[version='>=2017.4.17']
# sympy -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# cartopy -> matplotlib-base[version='>=1.5.1'] -> certifi[version='>=2020.06.20']
# pytest -> setuptools[version='>=40.0'] -> certifi[version='>=2016.09|>=2016.9.26']
# jupyterlab -> tornado[version='!=6.0.0,!=6.0.1,!=6.0.2'] -> certifi
# ...
# _ipyw_jlab_nb_ext_conf -> ipywidgets -> ipykernel[version='>=4.5.1']
# jupyterlab_server -> notebook[version='>=4.2.0'] -> ipykernel
#
# Package gmpy2 conflicts for:
# sympy -> gmpy2[version='>=2.0.8']
# anaconda==2021.05 -> sympy==1.8=py37h06a4308_0 -> gmpy2[version='>=2.0.8']
# anaconda==2021.05 -> gmpy2==2.0.8[build='py38hd5f6e3b_3|py39h8083e48_3|py37h10f8cd9_2']
#
# Package python-libarchive-c conflicts for:
# conda-package-handling -> python-libarchive-c
# conda-verify -> conda-package-handling[version='>=1.0.4'] -> python-libarchive-c
# anaconda==2021.05 -> python-libarchive-c==2.9=pyhd3eb1b0_1
# conda[version='>=4.10.1'] -> conda-package-handling[version='>=1.3.0'] -> python-libarchive-c
# conda-build -> python-libarchive-c
#
# Package lzo conflicts for:
# anaconda==2021.05 -> lzo==2.10=h7b6447c_2
# libarchive -> lzo[version='>=2.10,<3.0a0']
# anaconda==2021.05 -> pytables==3.6.1=py37h71ec239_0 -> lzo[version='>=2.10,<3.0a0']
# conda-build -> libarchive -> lzo[version='>=2.10,<3.0a0']
# python-libarchive-c -> libarchive -> lzo[version='>=2.10,<3.0a0']
# conda-package-handling -> libarchive[version='>=3.3.3'] -> lzo[version='>=2.10,<3.0a0']
# pytables -> lzo[version='2.*|>=2.10,<3.0a0']
#
# Package mypy_extensions conflicts for:
# pyls-black -> black -> mypy_extensions
# anaconda==2021.05 -> black==19.10b0=py_0 -> mypy_extensions
# anaconda==2021.05 -> mypy_extensions[version='0.4.1|0.4.3|0.4.3',build='py37_0|py39h06a4308_0|py38_0']
# black -> mypy_extensions
#
# Package astroid conflicts for:
# python-language-server -> pylint[version='>=2.5.0'] -> astroid[version='>=1.5.1|>=1.6,<2.0|>=2.0.0|>=2.2.0|>=2.3.0,<2.4|>=2.4.0,<2.5|>=2.4.0,<=2.5|>=2.5.8,<=2.7']
# anaconda==2021.05 -> astroid==2.5[build='py39h06a4308_1|py37h06a4308_1|py38h06a4308_1']
# spyder -> pylint[version='>=1.0'] -> astroid[version='>=1.5.1|>=1.6,<2.0|>=2.0.0|>=2.2.0|>=2.3.0,<2.4|>=2.4.0,<2.5|>=2.4.0,<=2.5|>=2.5.8,<=2.7']
# anaconda==2021.05 -> pylint==2.7.4=py37h06a4308_1 -> astroid[version='>=2.4.0,<=2.5']
# pylint -> astroid[version='>=1.5.1|>=1.6,<2.0|>=2.0.0|>=2.2.0|>=2.3.0,<2.4|>=2.4.0,<2.5|>=2.4.0,<=2.5|>=2.5.8,<=2.7']
#
# Package itsdangerous conflicts for:
# anaconda==2021.05 -> itsdangerous==1.1.0[build='py37_0|pyhd3eb1b0_0']
# flask -> itsdangerous[version='>=0.21|>=0.24']
# anaconda==2021.05 -> flask==1.1.2=pyhd3eb1b0_0 -> itsdangerous[version='>=0.24']
#
# Package ripgrep conflicts for:
# conda-build -> ripgrep
# anaconda==2021.05 -> ripgrep==12.1.1=0
#
# Package snowballstemmer conflicts for:
# python-language-server -> pydocstyle[version='>=2.0.0'] -> snowballstemmer
# anaconda==2021.05 -> snowballstemmer==2.1.0=pyhd3eb1b0_0
# sphinx -> snowballstemmer[version='>=1.1']
# numpydoc -> sphinx -> snowballstemmer[version='>=1.1']
# spyder -> sphinx[version='>=0.6.6'] -> snowballstemmer[version='>=1.1']
# anaconda==2021.05 -> pydocstyle==6.0.0=pyhd3eb1b0_0 -> snowballstemmer[version='>=1.1']
# pydocstyle -> snowballstemmer
#
# Package python-language-server conflicts for:
# pyls-black -> python-language-server
# anaconda==2021.05 -> python-language-server==0.36.2=pyhd3eb1b0_0
# anaconda==2021.05 -> pyls-black==0.4.6=hd3eb1b0_0 -> python-language-server[version='>=0.36.2|>=0.36.2,<1.0.0']
# spyder -> python-language-server[version='>=0.31.2,<0.32.0|>=0.31.9,<0.32.0|>=0.34.0,<1.0.0|>=0.36.1,<1.0.0|>=0.36.2,<1.0.0']
# spyder -> pyls-black[version='>=0.4.6'] -> python-language-server[version='>=0.36.2']
# pyls-spyder -> python-language-server[version='>=0.36.2']
#
# Package black conflicts for:
# anaconda==2021.05 -> black==19.10b0=py_0
# attrs -> hypothesis -> black[version='>=19.10b0']
# anaconda==2021.05 -> pyls-black==0.4.6=hd3eb1b0_0 -> black
# spyder -> pyls-black[version='>=0.4.6'] -> black
# pyls-black -> black
#
# Package networkx conflicts for:
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
# anaconda==2021.05 -> scikit-image==0.18.1=py37ha9443f7_0 -> networkx[version='>=2.0']
# anaconda==2021.05 -> networkx==2.5=py_0
#
# Package cython conflicts for:
# anaconda==2021.05 -> cython==0.29.23[build='py37h2531618_0|py39h2531618_0|py38h2531618_0']
# nltk -> gensim -> cython==0.29.23
#
# Package fribidi conflicts for:
# anaconda==2021.05 -> fribidi==1.0.10=h7b6447c_0
# anaconda==2021.05 -> pango==1.45.3=hd140c19_0 -> fribidi[version='>=1.0.9,<2.0a0']
# pango -> fribidi[version='>=1.0.2,<2.0a0|>=1.0.4,<2.0a0|>=1.0.5,<2.0a0|>=1.0.9,<2.0a0']
#
# Package scikit-learn conflicts for:
# anaconda==2021.05 -> scikit-learn==0.24.1[build='py37ha9443f7_0|py39ha9443f7_0|py38ha9443f7_0']
# nltk -> scikit-learn
#
# Package gst-plugins-base conflicts for:
# anaconda==2021.05 -> qt==5.9.7=h5867ecd_1 -> gst-plugins-base[version='>=1.14.0,<1.15.0a0']
# pyqt -> qt=5.9 -> gst-plugins-base[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0']
# qt -> gst-plugins-base[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0']
# anaconda==2021.05 -> gst-plugins-base==1.14.0=h8213a91_2
#
# Package olefile conflicts for:
# pillow -> olefile
# anaconda==2021.05 -> olefile==0.46[build='py_0|py37_0']
# bokeh -> pillow[version='>=7.1.0'] -> olefile
# anaconda==2021.05 -> pillow==8.2.0=py37he98fc37_0 -> olefile
# matplotlib-base -> pillow[version='>=6.2.0'] -> olefile
# imageio -> pillow -> olefile
# anaconda-navigator -> pillow -> olefile
# cartopy -> pillow -> olefile
# scikit-image -> pillow[version='>=4.3.0'] -> olefile
#
# Package fsspec conflicts for:
# dask -> fsspec[version='>=0.4.0|>=0.5.1|>=0.6.0']
# anaconda==2021.05 -> dask-core==2021.4.0=pyhd3eb1b0_0 -> fsspec[version='>=0.6.0']
# anaconda==2021.05 -> fsspec==0.9.0=pyhd3eb1b0_0
# distributed -> dask-core=2021.6.0 -> fsspec[version='>=0.6.0']
# scikit-image -> dask-core[version='>=0.15.0'] -> fsspec[version='>=0.4.0|>=0.5.1|>=0.6.0']
# dask-core -> fsspec[version='>=0.6.0']
#
# Package zope conflicts for:
# attrs -> zope
# gevent -> zope.interface -> zope
# zope.interface -> zope
# anaconda==2021.05 -> zope.interface==5.3.0=py37h27cfd23_0 -> zope
# anaconda==2021.05 -> zope==1.0[build='py38_1|py39h06a4308_1|py37_1']
# pytest -> attrs[version='>=17.2.0'] -> zope
#
# Package textdistance conflicts for:
# anaconda==2021.05 -> textdistance==4.2.1=pyhd3eb1b0_0
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> textdistance[version='>=4.2.0']
# spyder -> textdistance[version='>=4.2.0']
#
# Package sphinxcontrib-htmlhelp conflicts for:
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> sphinxcontrib-htmlhelp
# anaconda==2021.05 -> sphinxcontrib-htmlhelp==1.0.3=pyhd3eb1b0_0
# numpydoc -> sphinx -> sphinxcontrib-htmlhelp
# sphinx -> sphinxcontrib-htmlhelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-htmlhelp
#
# Package nbclassic conflicts for:
# anaconda==2021.05 -> nbclassic==0.2.6=pyhd3eb1b0_0
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> nbclassic[version='>=0.2,<1']
# anaconda==2021.05 -> jupyterlab==3.0.14=pyhd3eb1b0_1 -> nbclassic[version='>=0.2,<1']
# jupyterlab -> nbclassic[version='>=0.2,<1']
#
# Package three-merge conflicts for:
# spyder -> three-merge[version='>=0.1.1']
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> three-merge[version='>=0.1.1']
# anaconda==2021.05 -> three-merge==0.1.1=pyhd3eb1b0_0
#
# Package anaconda-project conflicts for:
# anaconda-navigator -> anaconda-project[version='>=0.4']
# anaconda==2021.05 -> anaconda-project==0.9.1=pyhd3eb1b0_1
#
# Package bkcharts conflicts for:
# anaconda==2021.05 -> bkcharts==0.2[build='py38_0|py39h06a4308_0|py37_0']
# bokeh -> bkcharts[version='>=0.2']
# dask -> bokeh -> bkcharts[version='>=0.2']
#
# Package diff-match-patch conflicts for:
# three-merge -> diff-match-patch
# anaconda==2021.05 -> diff-match-patch==20200713=py_0
# spyder -> diff-match-patch[version='>=20181111']
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> diff-match-patch[version='>=20181111']
#
# Package sphinx conflicts for:
# jedi -> numpydoc -> sphinx
# anaconda==2021.05 -> numpydoc==1.1.0=pyhd3eb1b0_1 -> sphinx[version='>=0.6.6']
# numpydoc -> sphinx
# spyder -> sphinx[version='>=0.6.6']
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0
#
# Package dask conflicts for:
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0
# scikit-image -> dask[version='>=0.5']
#
# Package wrapt conflicts for:
# anaconda==2021.05 -> wrapt==1.12.1[build='py37h7b6447c_1|py39he8ac12f_1|py38h7b6447c_1']
# anaconda==2021.05 -> astroid==2.5=py37h06a4308_1 -> wrapt[version='>=1.11,<2']
# astroid -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# pylint -> astroid[version='>=2.5.8,<=2.7'] -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
#
# Package pywavelets conflicts for:
# scikit-image -> pywavelets[version='>=0.4.0']
# anaconda==2021.05 -> scikit-image==0.18.1=py37ha9443f7_0 -> pywavelets[version='>=0.4.0']
# anaconda==2021.05 -> pywavelets==1.1.1[build='py39h6323ea4_4|py37h7b6447c_2|py38h7b6447c_2']
#
# Package py-lief conflicts for:
# conda-build -> py-lief
# anaconda==2021.05 -> py-lief==0.10.1[build='py38h403a769_0|py39h2531618_1|py37h403a769_0']
#
# Package qdarkstyle conflicts for:
# spyder -> qdarkstyle[version='3.0.2.*|>=2.8,<3.0|>=2.8|>=2.7']
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> qdarkstyle[version='>=2.8,<3.0']
# anaconda==2021.05 -> qdarkstyle==2.8.1=py_0
#
# Package llvmlite conflicts for:
# anaconda==2021.05 -> llvmlite==0.36.0[build='py37h612dafd_4|py39h612dafd_4|py38h612dafd_4']
# numba -> llvmlite[version='0.20.*|0.21.*|0.22.*|0.23.*|0.24.*|>=0.25.0,<0.26.0a0|>=0.26.0,<0.27.0a0|>=0.27.0,<0.28.0a0|>=0.28.0,<0.29.0a0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.32.0,<0.33.0a0|>=0.32.0|>=0.32.1,<0.33.0a0|>=0.32.1|>=0.33.0|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.34.0,<0.35|>=0.35.0,<0.36.0a0|>=0.36.0,<0.37.0a0',build=*_1]
# anaconda==2021.05 -> numba==0.53.1=py37ha9443f7_0 -> llvmlite[version='>=0.36.0,<0.37.0a0']
#
# Package wurlitzer conflicts for:
# anaconda==2021.05 -> wurlitzer==2.1.0[build='py38h06a4308_0|py37h06a4308_0|py39h06a4308_0']
# spyder-kernels -> wurlitzer[version='>=1.0.3']
# spyder -> spyder-kernels[version='>=2.0.3,<2.1.0'] -> wurlitzer[version='>=1.0.3']
# anaconda==2021.05 -> spyder-kernels==1.10.2=py37h06a4308_0 -> wurlitzer[version='>=1.0.3']
#
# Package pkginfo conflicts for:
# conda-build -> pkginfo
# anaconda==2021.05 -> pkginfo==1.7.0[build='py38h06a4308_0|py37h06a4308_0|py39h06a4308_0']
#
# Package patchelf conflicts for:
# anaconda==2021.05 -> patchelf==0.12=h2531618_1
# conda-build -> patchelf
#
# Package qtconsole conflicts for:
# jupyter -> qtconsole
# anaconda==2021.05 -> jupyter==1.0.0=py37_7 -> qtconsole[version='>=5.0.3']
# anaconda==2021.05 -> qtconsole==5.0.3=pyhd3eb1b0_0
# spyder -> qtconsole[version='>=4.2|>=4.6.0|>=4.7.7|>=5.0.1|>=5.0.3|>=5.1.0']
#
# Package jupyterlab_launcher conflicts for:
# jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
#
# Package tifffile conflicts for:
# scikit-image -> tifffile[version='>=2019.7.26']
# anaconda==2021.05 -> scikit-image==0.18.1=py37ha9443f7_0 -> tifffile[version='>=2019.7.26']
# anaconda==2021.05 -> tifffile[version='2020.10.1|2020.10.1|2021.4.8',build='py38hdd07704_2|py37hdd07704_2|pyhd3eb1b0_2']
#
# Package mpfr conflicts for:
# gmpy2 -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
# sympy -> gmpy2[version='>=2.0.8'] -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
# anaconda==2021.05 -> mpfr==4.0.2=hb69a4c5_1
# mpc -> mpfr[version='3.*|>=4.0.1,<5.0a0']
# anaconda==2021.05 -> gmpy2==2.0.8=py37h10f8cd9_2 -> mpfr[version='>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
# gmpy2 -> mpc -> mpfr
#
# Package _low_priority conflicts for:
# libarchive -> _low_priority
# python-libarchive-c -> libarchive -> _low_priority
# conda-build -> libarchive -> _low_priority
#
# Package zope.event conflicts for:
# anaconda==2021.05 -> gevent==21.1.2=py37h27cfd23_1 -> zope.event
# anaconda==2021.05 -> zope.event==4.5.0[build='py38_0|py39h06a4308_0|py37_0']
# gevent -> zope.event
#
# Package json5 conflicts for:
# anaconda==2021.05 -> jupyterlab_server==2.4.0=pyhd3eb1b0_0 -> json5
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> json5
# anaconda==2021.05 -> json5==0.9.5=py_0
# jupyterlab_server -> json5
#
# Package curl conflicts for:
# pycurl -> curl[version='7.55.*|>=7.55.1,<8.0a0']
# anaconda==2021.05 -> curl==7.71.1=hbc83047_1
#
# Package bleach conflicts for:
# notebook -> nbconvert -> bleach
# anaconda==2021.05 -> bleach==3.3.0=pyhd3eb1b0_0
# spyder -> nbconvert[version='>=4.0'] -> bleach
# jupyter -> nbconvert -> bleach
# jupyter_server -> nbconvert -> bleach
# anaconda==2021.05 -> nbconvert==6.0.7=py37_0 -> bleach
# nbconvert -> bleach
#
# Package libaec conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h581e88b_0 -> libaec[version='>=1.0.4,<2.0a0']
# anaconda==2021.05 -> libaec==1.0.4=he6710b0_1
# tifffile -> imagecodecs[version='>=2021.3.31'] -> libaec[version='>=1.0.4,<2.0a0']
#
# Package filelock conflicts for:
# conda-build -> filelock
# anaconda==2021.05 -> filelock==3.0.12=pyhd3eb1b0_1
#
# Package selectors2 conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
# wurlitzer -> selectors2
#
# Package brotlipy conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
# anaconda==2021.05 -> urllib3==1.26.4=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0']
# anaconda==2021.05 -> brotlipy==0.7.0[build='py38h27cfd23_1003|py37h27cfd23_1003|py39h27cfd23_1003']
# urllib3 -> brotlipy[version='>=0.6.0']
#
# Package liblief conflicts for:
# anaconda==2021.05 -> liblief==0.10.1[build='he6710b0_0|h2531618_1']
# py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0|0.8.3',build='h1532aa0_0|h1532aa0_0|h7725739_2|he6710b0_0|h2531618_1|h7725739_1']
# conda-build -> py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0|0.8.3',build='h1532aa0_0|h1532aa0_0|h7725739_2|he6710b0_0|h2531618_1|h7725739_1']
#
# Package backports.tempfile conflicts for:
# conda-build -> conda-verify -> backports.tempfile
# conda-verify -> backports.tempfile
#
# Package intervaltree conflicts for:
# anaconda==2021.05 -> intervaltree==3.1.0=py_0
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> intervaltree[version='>=3.0.2']
# spyder -> intervaltree[version='>=3.0.2']
#
# Package lxml conflicts for:
# anaconda==2021.05 -> lxml==4.6.3[build='py38h9120a33_0|py37h9120a33_0|py39h9120a33_0']
# cartopy -> owslib -> lxml
#
# Package libuv conflicts for:
# gevent -> libuv[version='>=1.40.0,<2.0a0']
# anaconda==2021.05 -> libuv==1.40.0=h7b6447c_0
# anaconda==2021.05 -> gevent==21.1.2=py37h27cfd23_1 -> libuv[version='>=1.40.0,<2.0a0']
#
# Package twisted conflicts for:
# jupyter_server -> prometheus_client -> twisted
# prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
#
# Package rtree conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> rtree[version='>=0.8.3']
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
# anaconda==2021.05 -> rtree==0.9.7[build='py39h06a4308_1|py37h06a4308_1|py38h06a4308_1']
#
# Package glob2 conflicts for:
# conda-build -> glob2[version='>=0.6']
# anaconda==2021.05 -> glob2==0.7=pyhd3eb1b0_0
#
# Package cryptography-vectors conflicts for:
# secretstorage -> cryptography -> cryptography-vectors=2.3
# pyopenssl -> cryptography[version='>=2.2.1'] -> cryptography-vectors=2.3
# conda-content-trust -> cryptography -> cryptography-vectors=2.3
# urllib3 -> cryptography[version='>=1.3.4'] -> cryptography-vectors=2.3
# cryptography -> cryptography-vectors=2.3
#
# Package conda-content-trust conflicts for:
# anaconda-navigator -> conda-token -> conda-content-trust
# conda-token -> conda-content-trust
#
# Package sniffio conflicts for:
# anaconda==2021.05 -> anyio==2.2.0=py37h06a4308_1 -> sniffio[version='>=1.1']
# anyio -> sniffio[version='>=1.1']
# jupyter_server -> anyio[version='>=2.0.2'] -> sniffio[version='>=1.1']
# anaconda==2021.05 -> sniffio==1.2.0[build='py39h06a4308_1|py37h06a4308_1|py38h06a4308_1']
#
# Package beautifulsoup4 conflicts for:
# anaconda==2021.05 -> beautifulsoup4==4.9.3=pyha847dfd_0
# conda-build -> beautifulsoup4
# anaconda==2021.05 -> soupsieve==2.2.1=pyhd3eb1b0_0 -> beautifulsoup4
# soupsieve -> beautifulsoup4
#
# Package backports.weakref conflicts for:
# backports.tempfile -> backports.weakref
# conda-verify -> backports.tempfile -> backports.weakref
# Note: you may need to restart the kernel to use updated packages.

# %%
import cartopy.crs as ccrs
import cartopy.feature as cf
import cartopy

import shapely.geometry as sgeom
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d77449575e92> in <module>
# ----> 1 import cartopy.crs as ccrs
#       2 import cartopy.feature as cf
#       3 import cartopy
#       4
#       5 import shapely.geometry as sgeom
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
# Crea una nueva figura (usada para el mapa), y la hace activa:
plt.figure()
# Agregar una nueva ventana (ejes) a la figura, definiendo el tipo de proyección que se utilizará 
ax = plt.axes(projection = ccrs.InterruptedGoodeHomolosine())
# Define que en esta ventana se usen bordes de las costas
ax.coastlines()
# plt.savefig('coastlines.pdf')  # Grabar el mapa (o en .png) ANTES de plt.show()
# Muestra la figura (mapa) embebida en el notebook
plt.show()
# Cierra la figura, asi se libera la memoria
plt.close()

# %%
plt.figure()
ax = plt.axes(projection = ccrs.Mollweide())
# Define que en esta ventana se usen imágenes 
# las imágenes son de https://www.naturalearthdata.com/downloads/50m-raster-data/50m-natural-earth-2/
ax.stock_img()
plt.show()
plt.close()

# %%
plt.figure()
ax = plt.axes(projection = ccrs.PlateCarree(central_longitude = -74))
ax.coastlines()

plt.show()
plt.close()

# %%
plt.figure()
ax = plt.axes(projection = ccrs.Robinson(central_longitude = -74))
ax.stock_img()

ax.gridlines(color='black', linestyle='--')

plt.show()
plt.close()

# %%
# Crea una nueva figura, definiendo un tamaño diferente al default: [6.4, 4.8]
plt.figure(figsize = [12, 9])
ax = plt.axes(projection = ccrs.PlateCarree())
ax.stock_img()

cali_lon, cali_lat = -76.59, 3.39
roma_lon, roma_lat = 12.39, 41.90

plt.plot([cali_lon, roma_lon], [cali_lat, roma_lat], 
         color = 'red', linewidth = 2, marker = 'o', 
         transform = ccrs.Geodetic(),
         )

plt.plot([cali_lon, roma_lon], [cali_lat, roma_lat],
         color = 'blue', linewidth = 2, linestyle = '--',
         transform = ccrs.PlateCarree(),
         )

plt.text(cali_lon - 2, cali_lat - 8, 'Cali',
         horizontalalignment = 'right',
         transform = ccrs.Geodetic())

plt.text(roma_lon + 2, roma_lat - 8, 'Roma',
         horizontalalignment = 'left',
         transform = ccrs.Geodetic())

plt.show()

# %%
plt.figure(figsize = (10, 8))
ax = plt.axes(projection = ccrs.AlbersEqualArea(-75, 7.5))
ax.set_extent([-80, -67, -5, 13])

ax.add_feature(cf.COASTLINE)
ax.add_feature(cf.LAND, edgecolor = 'black')
# ax.add_feature(cf.OCEAN)
ax.add_feature(cf.RIVERS)
ax.add_feature(cf.BORDERS, linestyle=':')

ax.gridlines(draw_labels = True, color = 'black', alpha = 0.5, linestyle = '--')

plt.show()
plt.close()

# %%
plt.figure(figsize = [10, 8])
ax = plt.axes(projection = ccrs.PlateCarree())
# ax.coastlines()

ax.stock_img()
ax.set_title("Ruta propuesta de Phileas Fogg")

places = {
    'londres': [-0.1276474, 51.5073219],
    'suez': [32.537086, 29.974498],
    'bombay': [72.8882172, 19.1334321],
    'calcuta': [88.3476023, 22.5677459],
    'hong kong': [114.1628131, 22.2793278],
    'yokohama': [139.636768, 35.444991],
    'san francisco': [-122.4629897, 37.7647993],
    'new york': [-73.9866136, 40.7306458]}

destinations = [
    'londres', 'suez', 'bombay', 'calcuta', 'hong kong',
    'yokohama', 'san francisco', 'new york', 'londres']

lons, lats = zip( *[ (places[place][0], places[place][1]) for place in destinations ] )

ax.plot(lons, lats,
        linestyle = '--', color = 'red', linewidth = 4,
        transform = ccrs.Geodetic())

plt.show()
plt.close()
